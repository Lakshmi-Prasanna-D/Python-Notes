# %%
s=set(map(int,input().split()))
n=len(s)
print(s)
print("length is:",n)
# Out:
#  1 2 1 3 4 2 5
# {1, 2, 3, 4, 5}
# length is: 5

# %%
import sys
def display():
    print(s)
def remove(x):
    return s.discard(x)
def add(x):
    s.add(x)
    
def isEmpty():
    if len(s)==0:
        return True;
    return False
s=set()
while True:
    print("1.check if set is empty\n 2.add element \n 3.remove element \n 4.display \n 5.exit")
    print("enter your choice:")
    ch=int(input())
    match(ch):
    
        case 1:
            if isEmpty():
                print("set is empty")
            else:
                print("set is not empty")
        case 2:
            x=int(input("enter element to add:"))
            add(x)
        case 3:
            x=int(input("enter element to delete"))
            print(f"removed {x}")
            print(s)
        case 4: 
           display()
        case 5:
            break
        case _:
            print("invalid")
# Out:
# 1.check if set is empty
#  2.add element
#  3.remove element
#  4.display
#  5.exit
# enter your choice:
#  6579
# invalid
# 1.check if set is empty
#  2.add element
#  3.remove element
#  4.display
#  5.exit
# enter your choice:
#  5

# %%
print("enter the elements:\n")
s=set(map(int,input().split()))
print(s)
sum1=sum(s)
print("average is:",(sum1/len(s)))
# Out:
# enter the elements:
#  1 2 1 3 1 4 5
# {1, 2, 3, 4, 5}
# average is: 3.0

# %%
print("enter the elements of set1:\n")
s1=set(map(int,input().split()))
print("enter the elements od set2:\n")
s2=set(map(int,input().split()))
print("Set1:\n",s1)
print("Set2:\n",s2)
print("union is:", s1.union(s2))
si=s1.intersection(s2)
print("Intersection is:",si)
# Out:
# enter the elements of set1:
#  1 2 3 4
# enter the elements od set2:
#  1 4 2 6
# Set1:
#  {1, 2, 3, 4}
# Set2:
#  {1, 2, 4, 6}
# union is: {1, 2, 3, 4, 6}
# Intersection is: {1, 2, 4}

# %%
print("enter the elements of set1:\n")
s1=set(map(int,input().split()))
print("enter the elements od set2:\n")
s2=set(map(int,input().split()))
print("Set1:\n",s1)
print("Set2:\n",s2)
print("difference btw s1 and s2:",(s1-s2))
print("difference btw s2 and s1",(s2-s1))
print("symmetric difference:",(s1-s2).union(s2-s1))
# Out:
# enter the elements of set1:
#  1 2 3 4
# enter the elements od set2:
#  3 4 5 7
# Set1:
#  {1, 2, 3, 4}
# Set2:
#  {3, 4, 5, 7}
# difference btw s1 and s2: {1, 2}
# difference btw s2 and s1 {5, 7}
# symmetric difference: {1, 2, 5, 7}

# %%
s1=set(map(int,input("enter set 1 elements:\n").split()))
print("using built -in")
print("max is:", max(s1))
m1=max(s1)
m2=min(s1)
print("min is:",m2)
print("range is:", (m1-m2))
# Out:
# enter set 1 elements:
#  1 2 3 4 5
# using built -in
# max is: 5
# min is: 1
# range is: 4

# %%
print("without using built-in\n")
maxi=-100000
mini=100000
for x in s1:
    if x>maxi:
        maxi=x
    if x<mini:
        mini=x
print("max is:",maxi)
print("min is :",mini)
print("range is::",(maxi-mini))
# Out:
# without using built-in
#
# max is: 5
# min is : 1
# range is:: 4

# %%
print("enter the elements of set1:\n")
s1=set(map(int,input().split()))
print("enter the elements of set2:\n")
s2=set(map(int,input().split()))
print("Set1:\n",s1)
print("Set2:\n",s2)
if s1<=s2:
    print("subset")
else:
    print("not subset")

if s1<s2:
    print("proper subset")
else:
    print("not a proper subset")
# Out:
# enter the elements of set1:
#  1 2 3 4 5
# enter the elements of set2:
#  2 3 4
# Set1:
#  {1, 2, 3, 4, 5}
# Set2:
#  {2, 3, 4}
# not subset
# not a proper subset

# %%
print("enter the elements of set1:\n")
s1=set(map(int,input().split()))
print("enter the elements od set2:\n")
s2=set(map(int,input().split()))
print("Set1:\n",s1)
print("Set2:\n",s2)
if s1>=s2:
    print("SuperSet")
else:
    print("not Superset")

if s1>s2:
    print("proper SuperSet")
else:
    print("not a proper Superset")
# Out:
# enter the elements of set1:
#  1 2 3 4 5
# enter the elements od set2:
#  1 2 3 4
# Set1:
#  {1, 2, 3, 4, 5}
# Set2:
#  {1, 2, 3, 4}
# SuperSet

# %%
print("enter the elements of set1:\n")
s1=set(map(int,input().split()))
print("enter the elements of set2:\n")
s2=set(map(int,input().split()))
print("Set1:\n",s1)
print("Set2:\n",s2)
disj=s1.isdisjoint(s2)
if disj:
    print("disjoint")
else:
    print ("not disjoint")
# Out:
# enter the elements of set1:
#  1 2 3 4 5
# enter the elements od set2:
#  3 4 5 6
# Set1:
#  {1, 2, 3, 4, 5}
# Set2:
#  {3, 4, 5, 6}
# not disjoint

# %%
print("enter the elements of list:\n")
l=list(map(int,input().split()))
print("using set")
print(l)
print("after removing duplicates:")
print(set(l))
l1=[]
for x in l:
    if x not in l1:
        l1.append(x)
print(l1)
# Out:
# enter the elements of list:
#  1 2 1 3 2 4
# using set
# [1, 2, 1, 3, 2, 4]
# after removing duplicates:
# {1, 2, 3, 4}
# [1, 2, 3, 4]

# %%
print("enter the elements of list:\n")
l=list(map(int,input().split()))
s=set(l)
if len(l)==len(s):
    print("unique")
else:
    print("not unique")
# Out:
# enter the elements of list:
#  1 3 1 6 0987
# not unique

# %%
n=int(input())
l=[]
while(n%2==0):
    l.append(2)
    n//=2
for i in range (3,n+1,2):
    if n%i==0:
        n//=i
        l.append(i)
if n>1:
    l.append(n) 
print(l)
# Out:
#  11
# [11]

# %%
n=int(input())
l=[]
while(n%2==0):
    l.append(2)
    n//=2
for i in range (3,n+1,2):
    if n%i==0:
        n//=i
        l.append(i)
if n>1:
    l.append(n) 
print(f"prime factors are:",set(l))
print("max factor is:",max(l))
print("min factor is :",min(l))
# Out:
#  99
# prime factors are: {11, 3}
# max factor is: 11
# min factor is : 3

# %%
print("enter the elements of set:\n")
l=list(map(int,input().split()))
print(l)
s=set(l)
c1=len(s)
print("unique count is: (using set)",c1)
l2=[]
for x in l:
    if x not in l2:
        l2.append(x)
print("unique count (without set):",len(l2))
# Out:
# enter the elements of set:
#  2 1 2 2 2 3 3 4 6
# [2, 1, 2, 2, 2, 3, 3, 4, 6]
# unique count is: (using set) 5
# unique count (without set): 5

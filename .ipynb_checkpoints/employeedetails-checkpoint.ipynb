# %%
n=int(input("enter n  value\n"))
l=[]
for i in range(n):
    l1=[]
    print(f"enter the following details of employee{i+1}")
    print("enter empid:")
    empid=int(input())
    print("enter name:")
    name=input()
    print("enter job:")
    job=input()
    print("enter salary:")
    salary=int(input())
    print("grade:")
    grade=input()
    print("location")
    location=input()
    l1=[empid,name,job,salary,grade,location]
    l.append(l1)
# Out:
# enter n  value
#  5
# enter the following details of employee1
# enter empid:
#  1
# enter name:
#  Sai
# enter job:
#  fsd
# enter salary:
#  10000
# grade:
#  A
# location
#  hyd
# enter the following details of employee2
# enter empid:
#  2
# enter name:
#  lakshmi
# enter job:
#  sde
# enter salary:
#  23440
# grade:
#  A
# location
#  Japan
# enter the following details of employee3
# enter empid:
#  3
# enter name:
#  Prasanna
# enter job:
#  HR
# enter salary:
#  98770
# grade:
#  A
# location
#  vizag
# enter the following details of employee4
# enter empid:
#  4
# enter name:
#  Pavana
# enter job:
#  Techies
# enter salary:
#  45000
# grade:
#  A
# location
#  JRg
# enter the following details of employee5
# enter empid:
#  5
# enter name:
#  Chaitu
# enter job:
#  Manager
# enter salary:
#  120000
# grade:
#  A
# location
#  pulla

# %%
print("the entered details are:")
print(l)
# Out:
# the entered details are:
# [[1, 'Sai', 'fsd', 10000, 'A', 'hyd'], [2, 'lakshmi', 'sde', 23440, 'A', 'Japan'], [3, 'Prasanna', 'HR', 98770, 'A', 'vizag'], [4, 'Pavana', 'Techies', 45000, 'A', 'JRg'], [5, 'Chaitu', 'Manager', 120000, 'A', 'pulla']]

# %%
print("1.sort by name\n 2.sort by job \n 3. sort by salary\n 4.sort by location \n 5.sort by job and salary \n 6.sort by grade and job \n 7.grade , salary and job")
# Out:
# 1.sort by name
#  2.sort by job
#  3. sort by salary
#  4.sort by location
#  5.sort by job and salary
#  6.sort by grade and job
#  7.grade , salary and job
# select your choice:
#  1

# %%
#sort by name
print("select your choice:")
ch=int(input())
match ch:
    case 1:
        name=sorted(l,key=lambda x:x[1])
        print(name)
    case 2:
        job=sorted(l,key=lambda x:x[2])
        print(job)
    case 3:
        salary=sorted(l,key=lambda x:x[3])
        print(salary)
    case 4:
        location=sorted(l,key=lambda x:x[5])
        print(location)
    case 5:
        job_salary=sorted(l,key=lambda x:(x[2],x[3]))
        print(job_salary)
    case 6: 
        grade_job=sorted(l,key=lambda x:(x[4],x[2]))
        print(grade_job)
    case 7:
        grade_salary_job(l,key=lambda x:(x[4],x[3],x[2]))
# Out:
# select your choice:
#  1
# [[5, 'Chaitu', 'Manager', 120000, 'A', 'pulla'], [4, 'Pavana', 'Techies', 45000, 'A', 'JRg'], [3, 'Prasanna', 'HR', 98770, 'A', 'vizag'], [1, 'Sai', 'fsd', 10000, 'A', 'hyd'], [2, 'lakshmi', 'sde', 23440, 'A', 'Japan']]

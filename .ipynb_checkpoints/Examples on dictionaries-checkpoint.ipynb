# %%
n=int(input("enter size of list:"))
l=[]
for i in range(n):
    x=int(input(f"enter element {i+1}"))
    l.append(x)
print(l)
d={}
for x in l:
    if x in d:
        d[x]+=1
    else:
        d[x]=1
print(d)
# Out:
# enter size of list: 5
# enter element 1 1
# enter element 2 2
# enter element 3 2
# enter element 4 2
# enter element 5 1
# [1, 2, 2, 2, 1]
# {1: 2, 2: 3}

# %%
d1=dict(sorted(d.items()))
print(d1)
# Out:
# {1: 2, 2: 3}

# %%
d1=dict(sorted(d.items(),key=lambda x:x[1],reverse=1))
print(d1)
li=[]
for x in l:
    li.append(d[x])
print(li)
# Out:
# {2: 3, 1: 2}
# [2, 3, 3, 3, 2]

# %%
d1=dict(sorted(d.items(),key=lambda x:x[1],reverse=1))
li=[]
m=0
for y in d.values():
    if y>m:
        m=y
for x,y in d.items():
    if y==m:
        li.append(x)
print(li)
# Out:
# [2]

# %%
d1=dict(sorted(d.items(),key=lambda x:x[1],reverse=1))
li=[]
m=0
for y in d.values():
    if y>m:
        m=y
for x,y in d.items():
    if y==m:
        li.append((x,y))
print(li)
# Out:
# [(2, 3)]

# %%
d1=dict(sorted(d.items(),key=lambda x:x[1],reverse=1))
li=[]
m=0
for y in d.values():
    if y>m:
        m=y
for x,y in d.items():
    if y==m:
        li.append(x)
mval=-1
for x in li:
    if x>mval:
        mval=x
print("max value is:",mval)
# Out:
# max value is: 2

# %%
d1=dict(sorted(d.items(),key=lambda x:x[1],reverse=1))
li=[]
m=0
for y in d.values():
    if y>m:
        m=y
for x,y in d.items():
    if y==m:
        li.append(x)
mval=-1
for x in li:
    if x>mval:
        mval=x
print("max value is:",mval)
    v

# %%
n=int(input("enter size of list:"))
l=[]
for i in range(n):
    x=int(input(f"enter element {i+1}"))
    l.append(x)
d={}
for x in l:
    if x in d:
        d[x]+=1
    else:
        d[x]=1
print(d)
print(l)
d1=dict(sorted(d.items(),key=lambda x:x[1],reverse=1))
li=[]
m=0
for y in d.values():
    if y>m:
        m=y
for x,y in d.items():
    if y==m:
        li.append(x)
mval=-1
for x in li:
    if x>mval:
        mval=x
print("max value is:",mval)
# Out:
# enter size of list: 5
# enter element 1 1
# enter element 2 2
# enter element 3 3
# enter element 4 4
# enter element 5 5
# {1: 1, 2: 1, 3: 1, 4: 1, 5: 1}
# [1, 2, 3, 4, 5]
# max value is: 5

# %%
li=[]
m=0
for y in d.values():
    if y>m:
        m=y
for x,y in d.items():
    if y==m:
        li.append(x)
print("count is:",len(li))
# Out:
# count is: 5

# %%
li=[]
m=1000
for y in d.values():
    if y<m:
        m=y
for x,y in d.items():
    if y==m:
        li.append(x)
print(li)
# Out:
# [1, 2, 3, 4, 5]

# %%
li=[]
m=1000
for y in d.values():
    if y<m:
        m=y
for x,y in d.items():
    if y==m:
        li.append(x)
li=sorted(li)
print(li[0])
# Out:
# 1

# %%
l=list(map(int,input("enter the elements of list:\n").split()))
d={}
for x in l:
    if x in d:
        d[x]+=1
    else:
        d[x]=1
print(d)
k=int(input("enter k:"))
for x,y in d.items():
    if  y==k:
        print(x,end=" ")
# Out:
# enter the elements of list:
#  1 2 2 2 1
# {1: 2, 2: 3}
# enter k: 2
# 1

# %%
l=list(map(int,input("enter the elements of list:\n").split()))
d={}
for x in l:
    if x in d:
        d[x]+=1
    else:
        d[x]=1
print(d)
c=0
k=int(input("enter k:"))
for x,y in d.items():
    if  y==k:
        c+=1
print(f"count of elements with fequency {k}:",c)
# Out:
# enter the elements of list:
#  1 2 2 2 1
# {1: 2, 2: 3}
# enter k: 2
# count of elements with fequency 2: 1

# %%
l=list(map(int,input("enter the elements of list:\n").split()))
d={}
for x in l:
    if x in d:
        d[x]+=1
    else:
        d[x]=1

c=0
for x in d.keys():
    print(x,end=" ")
    
print(f"\ncount of elements after removing duplicates:",len(d))
# Out:
# enter the elements of list:
#  1 2  3 2 1 2 4 5
# 1 2 3 4 5
# count of elements after removing duplicates: 5

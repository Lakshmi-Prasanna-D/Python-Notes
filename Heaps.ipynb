# %%
import heapq as hp
l=[]
print("1.Add element\n 2.Delete Element \n 3.Find peek element \n 4.Exit")
while 1:
    print("enter your choice:")
    ch=int(input())
    match (ch):
        case 1:
            x=int(input("enter value to enter:"))
            hp.heappush(l,x)
        case 2:
            if len(l)!=0:
                print(f"deleted element:{hp.heappop(l)}")
                
            else:
                print("heap empty")
        case 3:
            if len(l)!=0:
                print(f"peek element is:",l[0])
            else:
                print("heap empty")
        case 4:
            break
        case _:
            print("invalid")
# Out:
# 1.Add element
#  2.Delete Element
#  3.Find peek element
#  4.Exit
# enter your choice:
#  1
# enter value to enter: 12
# enter your choice:
#  1
# enter value to enter: 12
# enter your choice:
#  2
# deleted element:12
# enter your choice:
#  2
# deleted element:12
# enter your choice:
#  34
# invalid
# enter your choice:
#  1
# enter value to enter: 12
# enter your choice:
#  2
# deleted element:12
# enter your choice:
#  2
# heap empty
# enter your choice:
#  3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 18
#       5 print("enter your choice:")
#       6 ch=int(input())
#       7 match (ch):
#       8     case 1:
#       9         x=int(input("enter value to enter:"))
#      10         hp.heappush(l,x)
#      11     case 2:
#      12         if len(l)!=0:
#      13             print(f"deleted element:{hp.heappop(l)}")
#      14
#      15         else:
# ...

# %%
import heapq as hp
l=[]

print("1.Add element\n 2.Delete Element \n 3.Find peek element \n 4.Exit")
while 1:
    print("enter your choice:")
    ch=int(input())
    match (ch):
        case 1:
            x=int(input("enter value to enter:"))
            hp.heappush(l,x)
            hp._heapify_max(l)
        case 2:
            if len(l)!=0:
                print(f"deleted element:{hp.heappop(l)}")
               hp._heapify_max(l)
                
            else:
                print("heap empty")
        case 3:
            if len(l)!=0:
                print(f"peek element is:",l[0])
            else:
                print("heap empty")
        case 4:
            break
        case _:
            print("invalid")
# Out:
# 1.Add element
#  2.Delete Element
#  3.Find peek element
#  4.Exit
# enter your choice:
#  1
# enter value to enter: 12
# enter your choice:
#  1
# enter value to enter: 4
# enter your choice:
#  1
# enter value to enter: 6
# enter your choice:
#  2
# deleted element:4
# enter your choice:
#  4

# %%
#max product of 3 numbers using max heap
l=list(map(int,input().split()))
hp._heapify_max(l)
prod=1
for i in range(3):
    prod*=hp.heappop(l)
    hp._heapify_max(l)
print(prod)
# Out:
#  1 2 3 4 5
# 60

# %%
#max product of 3 numbers using max heap when negatives exists
l=list(map(int,input().split()))
li=l[:]
hp._heapify_max(l)
prod1=1;prod2=1
maxi=1
peek=l[0]
for i in range(3):
    prod1*=hp.heappop(l)
    hp._heapify_max(l)
hp.heapify(li)
for i in range(2):
    prod2*=hp.heappop(li)
prod2*=peek
print("max is :",max(prod1,prod2) )
# Out:
#  1 2 3  4
# max is : 24

# %%
#find the minimum element using min heap
l=list(map(int,input("enter the elements:").split()))
hp.heapify(l)
print("minimum element is:",hp.heappop(l))
# Out:
# enter the elements: 1 2 1 3 1  5
# minimum element is: 1

# %%
#find the minimum element using min heap
l=list(map(int,input("enter the elements:").split()))
hp.heapify(l)
k=int(input("enter k value:"))
val=hp.nsmallest(3,l)
print("minimum element is:",val[-1])
# Out:
# enter the elements: 1 2 5 2 1
# enter k value: 3
# minimum element is: 2

# %%
#find the minimum element using min heap
l=list(map(int,input("enter the elements:").split()))
hp.heapify(l)
print("Ascending order is:\n")
while len(l)!=0:
    print(hp.heappop(l),end=" ")
# Out:
# enter the elements: 9 3 6 1 5 1
# Ascending order is:
#
# 1 1 3 5 6 9

# %%
#find the minimum element using min heap
l=list(map(int,input("enter the elements:").split()))
hp._heapify_max(l)
print("Descending  order is:\n")
while len(l)!=0:
    print(hp.heappop(l),end=" ")
    hp._heapify_max(l)
# Out:
# enter the elements: 9 4 2 6 1 8
# Descending  order is:
#
# 9 8 6 4 2 1
